# %% [markdown]
# # ResNet Transfer for NHTS

# %% [markdown]
# This script practices the following things in PyTorch. \
# 1) data preprocessing with data loader. \
# 2) Simple but quick visualization tools. \
# 3) ResNet transfer learning for RGB images. \

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import util

# torch model
import torch
import torch.nn as nn
import torch.nn.functional as F

# torch images
from torch.utils.data import TensorDataset, DataLoader
import torchvision
from torchvision import datasets, models, transforms
from PIL import Image

# %%
# read data; It takes 20 minutes without mmap_mode(!!!).
# this mmap_mode is super useful.
x_train_images_ = np.load("data_shenhao/nhts/x_train_rgb_images.npy", mmap_mode = 'r')
x_test_images_ = np.load("data_shenhao/nhts/x_test_rgb_images.npy", mmap_mode = 'r')

# %%
# read y.
y_train_ = np.load("data_shenhao/nhts/y_train.npy")
y_test_ = np.load("data_shenhao/nhts/y_test.npy")

# %%
# print("The sample size of training set is: ", x_train_nhts.shape[0])
# print("The sample size of testing set is: ", x_test_nhts.shape[0])
print("Training image shape: ", x_train_images_.shape)
print("Testing image shape: ", x_test_images_.shape)
# Out:
# Training image shape:  (26144, 3, 200, 200)
# Testing image shape:  (6537, 3, 200, 200)

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Data Preparation

# %%
# you need to use only a subset here. The full set is REALLY SLOW for debugging...
# size = 2000
x_train_images = x_train_images_[:, :, :, :]
x_test_images = x_test_images_[:, :, :, :]
y_train = y_train_[:]
y_test = y_test_[:]

# %%
y_train[y_train > 2] = 3
y_test[y_test > 2] = 3

# %%
y_train = y_train[:,np.newaxis].astype('int')
y_test = y_test[:,np.newaxis].astype('int')
print(y_train)
print(y_test)
# Out:
# [[2]
#  [1]
#  [2]
#  ...
#  [2]
#  [2]
#  [1]]
# [[2]
#  [1]
#  [2]
#  ...
#  [2]
#  [3]
#  [2]]

# %% [markdown]
# ## Transform & Visualization
# Two ways to transform. \
# 1) Potentially use the torchvision.transforms. However, then you have to iteratre over each image with PIL Image. It can be very slow.
# 2) Customize the transformation by yourself in numpy...

# %%
# specify data type. 
x_train_images=x_train_images.astype("float32")
x_test_images=x_test_images.astype("float32")
y_train=y_train.astype("int")
y_test=y_test.astype("int")

# %%
# transform.
# normalize to [0,1]
x_train_images_norm = x_train_images/255
x_test_images_norm = x_test_images/255

# to torch
x_train_torch = torch.from_numpy(x_train_images_norm)
x_test_torch = torch.from_numpy(x_test_images_norm)
y_train_torch = torch.from_numpy(y_train)
y_test_torch = torch.from_numpy(y_test)

print(x_train_torch.size())
print(x_test_torch.size())
print(y_train_torch.size())
print(y_test_torch.size())
# Out:
# torch.Size([26144, 3, 200, 200])
# torch.Size([6537, 3, 200, 200])
# torch.Size([26144, 1])
# torch.Size([6537, 1])

# %%
# use data loader: train and test. 
train_ds = TensorDataset(x_train_torch, y_train_torch)
batch_size = 500
train_dl = DataLoader(train_ds, batch_size, shuffle = True)

test_ds = TensorDataset(x_test_torch, y_test_torch)
batch_size = 500
test_dl = DataLoader(test_ds, batch_size, shuffle = True)

# %%
# visualize with torchvision.
images_, labels_ = iter(train_dl).next()
images = images_[:5,] # visualize five images
labels = labels_[:5,] # visualize five images

def imshow(img):
#     img = img * 255.0     # unnormalize
    npimg = img.numpy()
    plt.figure(figsize = (15,3))
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()
    
imshow(torchvision.utils.make_grid(images))
print(labels.numpy()[:,0])
# Out:
# [2 1 3 0 2]

# %%
# Naive CNN model
class Net(nn.Module):
    # sw: again. It is critical to understand the dimension transformation.
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(3, 6, 5)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(6, 16, 5)
        self.fc1 = nn.Linear(16 * 47 * 47, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 4)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = x.view(-1, 16 * 47 * 47)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

net = Net()
net.to(device)

# # test
# images, labels = iter(train_dl).next()
# output = net(images)
# print(output.size())

# %%
import torch.optim as optim

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9)
n_epoch = 10

# %%
for epoch in range(2):  # loop over the dataset multiple times
    # sw: learn the way of printing out the total loss for each batch.
    running_loss = 0.0
    for inputs, labels in train_dl:

        # forward + backward + optimize
        outputs = net(inputs)
        loss = criterion(outputs, labels)
        loss.backward()

        optimizer.step()
        optimizer.zero_grad() 
        
        # print statistics
        running_loss += loss.item()
    print(epoch, running_loss)
#         if i % 2000 == 1999:    # print every 2000 mini-batches
#             print('[%d, %5d] loss: %.3f' %
#                   (epoch + 1, i + 1, running_loss / 2000))
#             running_loss = 0.0
# print('Finished Training')
# Out:
# ------------------------------------------------------------------
# NameError                        Traceback (most recent call last)
# <ipython-input-70-aa339b8f573b> in <module>
#       2     # sw: learn the way of printing out the total loss for each batch.
#       3     running_loss = 0.0
# ----> 4     for i, data in enumerate(trainloader, 0):
#       5         # Q: Why do we need this enumerate(trainloader, 0)?
#       6         # get the inputs; data is a list of [inputs, labels]
#
# NameError: name 'trainloader' is not defined

# %%
# Out:
# torch.Size([500, 4])

# %%
# ResNet transfer model

# %%
type(x_train_images[0,0,0,0])

# %%
x_train_images[0,:,:,:].shape
# Out:
# (3, 200, 200)

# %%
util.imshow(np.moveaxis(x_train_images[0,:,:,:], 0, 2).astype('uint8'))

# %%
Image.fromarray(np.moveaxis(x_train_images[0,:,:,:], 0, 2).astype('uint8'))
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F37184291D0>

# %%
array = np.zeros([100, 200, 3], dtype=np.uint8)
array[:,:100] = [255, 128, 0] #Orange left side
array[:,100:] = [0, 0, 255]   #Blue right side

# %%
array.shape

# %%
x_train_images[0,:,:,:].shape

# %%
np.moveaxis(x_train_images[0,:,:,:], 0, 2).shape

# %%
# define transform 
transform = transforms.Compose(
    [transforms.ToPILImage()
#      transforms.ToTensor(),
        # sw: this line above seems necessary since all transformation in torchvision is designed for PIL images.
#      transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
    ])

inputs_train = transform(np.moveaxis(x_train_images[:10,:,:,:], 1, 3))
# targets_train = torch.from_numpy(y_train)
# inputs_test = transform(x_test_images)
# targets_test = torch.from_numpy(y_test)
# Out:
# ------------------------------------------------------------------
# ValueError                       Traceback (most recent call last)
# <ipython-input-16-a8fd5d1b8797> in <module>
#       7     ])
#       8
# ----> 9 inputs_train = transform(np.moveaxis(x_train_images[:10,:,:,:], 1, 3))
#      10 # targets_train = torch.from_numpy(y_train)
#      11 # inputs_test = transform(x_test_images)
#
# ~/anaconda3/lib/python3.7/site-packages/torchvision/transforms/transforms.py in __call__(self, img)
#      68     def __call__(self, img):
#      69         for t in self.transforms:
# ---> 70             img = t(img)
#      71         return img
#      72
#
# ~/anaconda3/lib/python3.7/site-packages/torchvision/transforms/transforms.py in __call__(self, pic)
#     134
#     135         """
# --> 136         return F.to_pil_image(pic, self.mode)
#     137
#     138     def __repr__(self):
#
# ~/anaconda3/lib/python3.7/site-packages/torchvision/transforms/functional.py in to_pil_image(pic, mode)
#     130     elif isinstance(pic, np.ndarray):
#     131         if pic.ndim not in {2, 3}:
# --> 132             raise ValueError('pic should be 2/3 dimensional. Got {} dimensions.'.format(pic.ndim))
#     133
#     134         elif pic.ndim == 2:
#
# ValueError: pic should be 2/3 dimensional. Got 4 dimensions.

# %%
x_train_images[0,:,:,:].shape

# %%
# compute size
